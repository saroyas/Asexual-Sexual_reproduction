# %%
import matplotlib.pyplot as plt
import itertools
import random
import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.ndimage import convolve
from operator import itemgetter
from itertools import groupby
# %matplotlib inline
import statistics

# %%
class world():
    def __init__(self, energy = 800*20, time = 0, outside_kill_zone = 500, initial_species_mean = 500, sd=50, loci = 20, total_pop = 2000, replication_ratio = 1.2):
        '''
        NOTE; SEXUAL IS REALLY HERMAPHRODITIC IN THIS PROGRAM
        we want here a fitness landscape, how much energy the world can provide for each time unit - 
        which has some notion of disaster and greatness incorporated into it - i.e. it fluctuates.
        The fitness function defines what proportion of teh energy each organism recieves
        then the energy defines how likely an organism is to survive - maybe also how likely they are to reproduce
        '''
        self.energy = energy # LATER WE MAKE THIS A SORTOFF RANDOM FUNCTION OF TIME PERIOD
        self.loci = loci
        self.outside_kill_zone = outside_kill_zone
        self.initial_species_mean = initial_species_mean
        self.total_pop_mat = (np.random.normal(self.initial_species_mean, sd, (loci, total_pop))).astype(int)
        self.species_sep_index = int(total_pop/2)
        self.fitness_array = []
        self.replication_ratio = replication_ratio
    
    def kill_organisms(self, kill_list):
        # AGAIN WE NEED TO GENERALISE THIS, BUT FOR NOW IT WORKS WITH TWO SPECIES
        self.total_pop_mat = np.delete(self.total_pop_mat, kill_list, axis=1)
        old_index = self.species_sep_index
        self.species_sep_index = old_index - len(np.where(kill_list<old_index))

        
    def outside_region_kill(self):
        #here we want to kill any organisms that fall into the kill zone
        #this kill zone is defined as when any gene number is self.insta_kill_zone away from the orignal mean (1000)
        outside_kill_zone = self.outside_kill_zone
        killer_gene_locations = np.where(abs(self.gen_tot_pop_mat()-self.initial_species_mean)>outside_kill_zone)
        kill_organisms = [x[1] for x in killer_gene_locations]
        self.kill_organisms(kill_organisms)
  
        
    def mutation_stage(self, step = 1, mutation_liklihood = 0.02):
        # OKAY, WHETHER OR NOT A MUTATION IS GOOD CRUCIALL DEPENDS ON THE FITNESS LANDSCAPE
        # IT WILL BE MORE GENERAL IF WE INDEED MAKE MUTATIONS RANDOM AND THE FITNESS LANDSCALE SUCH THAT MOST
        # RANDOM MUTATIONS ARE HARMFUL
        shape = (self.total_pop_mat).shape
        half_liklihood = mutation_liklihood/2
        mutation_matrix = np.random.choice([-step, 0, step], size=shape, p=[half_liklihood, 1-mutation_liklihood,half_liklihood])
        self.total_pop_mat = self.total_pop_mat + mutation_matrix
        
    def calc_fitness_array(self):
        pop_size = (self.total_pop_mat).shape[1]
        self.fitness_array = np.sum(self.total_pop_mat, axis=0)
        
    def survival_prob(self):
        #for now we will do a simple sum for fitness, this should lead to the population evolving to the corners 
        #of the allowed distribution. Later we will try more interesting and random fitness landscapes
        #with different levels of jaggedness
        self.calc_fitness_array()
        total_fitness = np.sum(self.fitness_array)
        prop_fitness = np.divide(self.fitness_array, total_fitness) # AGAIN THIS NEEDS TO BE RETHOUGHT
        return prop_fitness, total_fitness
    
    def survival_round(self):
        curr_pop_size = ((self.total_pop_mat).shape)[1]
        number_surviving = int(curr_pop_size * 0.8)
        curr_population_index = range(curr_pop_size)
        prop_fitness = (self.survival_prob())[0]
        survivor_list = np.random.choice(curr_population_index, number_surviving, replace = False, p = prop_fitness)
        self.total_pop_mat = (self.total_pop_mat)[:,survivor_list]

        old_index = self.species_sep_index

        self.species_sep_index = np.size(np.where(survivor_list<old_index))
        self.fitness_array = self.fitness_array[survivor_list]
    
            
    
    def asex_repl(self,asex_pop):
        size_of_parent_gen = asex_pop.shape[1]
        next_gen_size = int(size_of_parent_gen*(10/8))
        #in ASEXUAL REPLICATION, everyone living replicates, then the excess energy is used to
        # ramdomly replicate a few more organisms: next_gen_additionals
        next_gen_additional_size = next_gen_size - size_of_parent_gen
        next_gen_additional_chosen_index = random.sample(range(size_of_parent_gen), next_gen_additional_size)
        next_gen_additions = asex_pop[:, next_gen_additional_chosen_index]
        next_gen = np.concatenate([asex_pop, next_gen_additions], axis=1)
        return next_gen
    
    def mating_pairs(self, index_to_be_paired_and_mated, sex_pop):
        random.shuffle(index_to_be_paired_and_mated)
        offspring = []
        ones_loci = np.ones(shape = (1, self.loci))
        mating_pairs = zip(index_to_be_paired_and_mated[0::2], index_to_be_paired_and_mated[1::2])
        for pair in mating_pairs:
            (a,b) = pair
            parent_1 = sex_pop[:,a]
            parent_2 = sex_pop[:,b]
            parent_1_gene_index = np.random.randint(2, size=(1,self.loci))
            parent_1_genes = np.reshape(np.multiply(parent_1_gene_index, parent_1), (5))
            parent_2_gene_index = np.subtract(ones_loci, parent_1_gene_index)
            parent_2_genes = np.reshape(np.multiply(parent_2_gene_index, parent_2),(5))
            
            offspring_genes = np.add(parent_1_genes, parent_2_genes)
            offspring.append(offspring_genes)
        
        return offspring
    
    def sex_repl(self, sex_pop, mating_rounds = 2):
        #CURRENTLY GROSSLY INEFFICIENT, WE NEED TO MAKE THIS FASTER SOMEHOW
        
        size_of_parent_gen = sex_pop.shape[1]
        next_gen_size = int(size_of_parent_gen*(10/8))
        next_gen_additional_size = next_gen_size - 2*int(size_of_parent_gen/2)
        #WE RUN TWO BASIC ROUNDS OF REPLICATION
        #WHERE EVERYONE IS RANDOMLY PAIRED TO PRODUCE ONE OFFSPRING
        # WE NEED TO RECONSIDER THIS TO ACCOUNT FOR THE FACT THAT SEXUAL REPLICATION
        #IS A LOT SLOWER THAN ASEXUAL REPLICATION
        parents_index = list(range(size_of_parent_gen))
        
        if size_of_parent_gen%2 == 1:
            random.shuffle(parents_index)
            del parents_index[-1]
        
        #RIGHT NOW WE ONLY HAVE TWO MATING ROUNDS!, AND THEN THE EXTRA ENERGY ON AN EXTRA NOT FULL ROUND  
        #LATER WE MAY NEED TO GENERALISE TO FEWER
        offspring_from_full_rounds = (self.mating_pairs(parents_index, sex_pop)) + (self.mating_pairs(parents_index, sex_pop))
    
        chosen_for_rereplication = parents_index[:(2*next_gen_additional_size)]
        offspring_extra = self.mating_pairs(chosen_for_rereplication, sex_pop)
        total_offspring = np.asarray(offspring_from_full_rounds + offspring_extra)
        total_offspring = np.transpose(total_offspring)
        return total_offspring
        

        
    def replication_round(self):
        #HERE IS THE ONLY PLACE WHERE THE TWO SPECIES ARE CONSIDERED SEPERATELY
        #THIS IS WHERE THE species_sep_index becomes relevant
        #CURRENTLY WE DO REPLICATION NOT BASED ON FITNESS:
        #asex_fitness_array = self.fitness_array[0:self.species_sep_index]
        #total_asex_fitness = np.sum(asex_fitness_array)
        
        pop_size = (self.total_pop_mat).shape[1]
        
        asex_pop = self.total_pop_mat[:, 0:self.species_sep_index]
        sex_pop = self.total_pop_mat[:, self.species_sep_index:]
        new_asex_pop = self.asex_repl(asex_pop)
        new_sex_pop = self.sex_repl(sex_pop)
        print('NEW SEX POP SIZE:', new_sex_pop.shape)
        print('NEW ASEX POP SIZE', new_asex_pop.shape)
        self.total_pop_mat = np.concatenate([new_asex_pop,new_sex_pop], axis=1)
        self.species_sep_index = (new_asex_pop.shape)[1]
    
    def avg_fitness_by_type(self):
        asex_fitness_array = self.fitness_array[:self.species_sep_index]
        avg_asex_fitness = np.average(asex_fitness_array)
        
        sex_fitness_array = self.fitness_array[self.species_sep_index:]
        avg_sex_fitness = np.average(sex_fitness_array)
        
        return avg_asex_fitness, avg_sex_fitness

# %%
lengths = []
sexual_success = 0
asexual_success = 0
for i in range(10):
    gia = world(energy = 800*5, time=0, outside_kill_zone=500, initial_species_mean=500, sd = 50, loci=5, total_pop=1000, replication_ratio=1.2)
    total_population = [1000]
    for x in range(10000):
        gia.mutation_stage(step = 1, mutation_liklihood=0.02)
        gia.survival_round()
        gia.replication_round()
        if gia.species_sep_index>900:
            asexual_success += 1
            break
        if gia.species_sep_index<100:
            sexual_success+=1
            break
        print('ASEX AVG FITNESS: ', avg_asex_fitness)
        print('SEX AVG FITNESS: ', avg_sex_fitness)
    print('iteration: ',i)
    print(sexual_success, asexual_success)
    avg_asex_fitness, avg_sex_fitness = gia.avg_fitness_by_type()
    lengths.append(x)
# Out:
# PRE REPLICATION SEX POP SIZE: 400
# NEW SEX POP SIZE: (5, 500)
# (5, 500)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 396
# NEW SEX POP SIZE: (5, 495)
# (5, 505)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 381
# NEW SEX POP SIZE: (5, 476)
# (5, 523)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 386
# NEW SEX POP SIZE: (5, 482)
# (5, 516)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 389
# NEW SEX POP SIZE: (5, 486)
# (5, 511)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 375
# NEW SEX POP SIZE: (5, 468)
# (5, 527)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 371
# NEW SEX POP SIZE: (5, 463)
# (5, 531)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 360
# NEW SEX POP SIZE: (5, 450)
# (5, 543)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 355
# NEW SEX POP SIZE: (5, 443)
# (5, 548)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 359
# NEW SEX POP SIZE: (5, 448)
# (5, 541)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 366
# NEW SEX POP SIZE: (5, 457)
# (5, 531)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 359
# NEW SEX POP SIZE: (5, 448)
# (5, 538)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 360
# NEW SEX POP SIZE: (5, 450)
# (5, 535)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 348
# NEW SEX POP SIZE: (5, 435)
# (5, 550)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 347
# NEW SEX POP SIZE: (5, 433)
# (5, 551)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 354
# NEW SEX POP SIZE: (5, 442)
# (5, 541)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 356
# NEW SEX POP SIZE: (5, 445)
# (5, 537)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 356
# NEW SEX POP SIZE: (5, 445)
# (5, 536)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 348
# NEW SEX POP SIZE: (5, 435)
# (5, 545)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 548)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 349
# NEW SEX POP SIZE: (5, 436)
# (5, 542)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 546)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 545)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 347
# NEW SEX POP SIZE: (5, 433)
# (5, 541)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 542)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 355
# NEW SEX POP SIZE: (5, 443)
# (5, 528)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 353
# NEW SEX POP SIZE: (5, 441)
# (5, 528)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 344
# NEW SEX POP SIZE: (5, 430)
# (5, 538)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 545)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 327
# NEW SEX POP SIZE: (5, 408)
# (5, 557)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 561)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 552)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 540)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 337
# NEW SEX POP SIZE: (5, 421)
# (5, 540)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 343
# NEW SEX POP SIZE: (5, 428)
# (5, 531)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 337
# NEW SEX POP SIZE: (5, 421)
# (5, 537)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 339
# NEW SEX POP SIZE: (5, 423)
# (5, 533)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 523)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 522)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 343
# NEW SEX POP SIZE: (5, 428)
# (5, 523)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 342
# NEW SEX POP SIZE: (5, 427)
# (5, 522)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 517)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 525)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 326
# NEW SEX POP SIZE: (5, 407)
# (5, 538)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 308
# NEW SEX POP SIZE: (5, 385)
# (5, 560)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 297
# NEW SEX POP SIZE: (5, 371)
# (5, 573)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 563)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 575)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 300
# NEW SEX POP SIZE: (5, 375)
# (5, 566)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 575)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 575)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 291
# NEW SEX POP SIZE: (5, 363)
# (5, 576)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 283
# NEW SEX POP SIZE: (5, 353)
# (5, 585)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 284
# NEW SEX POP SIZE: (5, 355)
# (5, 582)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 570)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 295
# NEW SEX POP SIZE: (5, 368)
# (5, 566)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 296
# NEW SEX POP SIZE: (5, 370)
# (5, 563)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 558)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 556)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 307
# NEW SEX POP SIZE: (5, 383)
# (5, 545)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 547)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 307
# NEW SEX POP SIZE: (5, 383)
# (5, 542)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 530)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 311
# NEW SEX POP SIZE: (5, 388)
# (5, 536)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 528)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 525)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 521)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 521)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 512)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 517)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 516)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 321
# NEW SEX POP SIZE: (5, 401)
# (5, 513)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 321
# NEW SEX POP SIZE: (5, 401)
# (5, 512)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 506)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 501)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 498)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 331
# NEW SEX POP SIZE: (5, 413)
# (5, 495)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 340
# NEW SEX POP SIZE: (5, 425)
# (5, 482)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 496)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 487)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 346
# NEW SEX POP SIZE: (5, 432)
# (5, 471)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 471)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 343
# NEW SEX POP SIZE: (5, 428)
# (5, 472)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 343
# NEW SEX POP SIZE: (5, 428)
# (5, 471)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 344
# NEW SEX POP SIZE: (5, 430)
# (5, 468)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 347
# NEW SEX POP SIZE: (5, 433)
# (5, 463)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 353
# NEW SEX POP SIZE: (5, 441)
# (5, 453)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 355
# NEW SEX POP SIZE: (5, 443)
# (5, 450)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 352
# NEW SEX POP SIZE: (5, 440)
# (5, 452)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 344
# NEW SEX POP SIZE: (5, 430)
# (5, 461)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 342
# NEW SEX POP SIZE: (5, 427)
# (5, 462)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 337
# NEW SEX POP SIZE: (5, 421)
# (5, 467)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 332
# NEW SEX POP SIZE: (5, 415)
# (5, 472)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 475)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 326
# NEW SEX POP SIZE: (5, 407)
# (5, 477)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 481)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 485)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 498)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 303
# NEW SEX POP SIZE: (5, 378)
# (5, 501)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 305
# NEW SEX POP SIZE: (5, 381)
# (5, 497)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 308
# NEW SEX POP SIZE: (5, 385)
# (5, 492)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 311
# NEW SEX POP SIZE: (5, 388)
# (5, 487)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 309
# NEW SEX POP SIZE: (5, 386)
# (5, 488)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 493)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 310
# NEW SEX POP SIZE: (5, 387)
# (5, 485)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 488)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 487)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 313
# NEW SEX POP SIZE: (5, 391)
# (5, 477)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 310
# NEW SEX POP SIZE: (5, 387)
# (5, 480)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 486)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 497)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 503)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 282
# NEW SEX POP SIZE: (5, 352)
# (5, 510)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 501)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 493)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 308
# NEW SEX POP SIZE: (5, 385)
# (5, 473)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 311
# NEW SEX POP SIZE: (5, 388)
# (5, 468)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 460)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 482)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 480)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 472)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 311
# NEW SEX POP SIZE: (5, 388)
# (5, 462)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 301
# NEW SEX POP SIZE: (5, 376)
# (5, 473)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 476)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 286
# NEW SEX POP SIZE: (5, 357)
# (5, 490)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 283
# NEW SEX POP SIZE: (5, 353)
# (5, 492)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 278
# NEW SEX POP SIZE: (5, 347)
# (5, 497)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 284
# NEW SEX POP SIZE: (5, 355)
# (5, 488)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 282
# NEW SEX POP SIZE: (5, 352)
# (5, 490)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 285
# NEW SEX POP SIZE: (5, 356)
# (5, 485)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 281
# NEW SEX POP SIZE: (5, 351)
# (5, 488)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 280
# NEW SEX POP SIZE: (5, 350)
# (5, 488)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 285
# NEW SEX POP SIZE: (5, 356)
# (5, 481)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 291
# NEW SEX POP SIZE: (5, 363)
# (5, 472)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 462)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 309
# NEW SEX POP SIZE: (5, 386)
# (5, 447)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 307
# NEW SEX POP SIZE: (5, 383)
# (5, 448)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 311
# NEW SEX POP SIZE: (5, 388)
# (5, 441)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 314
# NEW SEX POP SIZE: (5, 392)
# (5, 436)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 453)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 300
# NEW SEX POP SIZE: (5, 375)
# (5, 450)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 304
# NEW SEX POP SIZE: (5, 380)
# (5, 445)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 309
# NEW SEX POP SIZE: (5, 386)
# (5, 438)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 441)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 440)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 309
# NEW SEX POP SIZE: (5, 386)
# (5, 435)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 302
# NEW SEX POP SIZE: (5, 377)
# (5, 442)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 301
# NEW SEX POP SIZE: (5, 376)
# (5, 442)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 291
# NEW SEX POP SIZE: (5, 363)
# (5, 453)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 441)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 446)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 452)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 451)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 284
# NEW SEX POP SIZE: (5, 355)
# (5, 455)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 284
# NEW SEX POP SIZE: (5, 355)
# (5, 455)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 286
# NEW SEX POP SIZE: (5, 357)
# (5, 452)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 284
# NEW SEX POP SIZE: (5, 355)
# (5, 453)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 441)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 446)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 445)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 285
# NEW SEX POP SIZE: (5, 356)
# (5, 448)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 438)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 283
# NEW SEX POP SIZE: (5, 353)
# (5, 448)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 279
# NEW SEX POP SIZE: (5, 348)
# (5, 451)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 278
# NEW SEX POP SIZE: (5, 347)
# (5, 451)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 279
# NEW SEX POP SIZE: (5, 348)
# (5, 448)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 287
# NEW SEX POP SIZE: (5, 358)
# (5, 436)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 427)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 288
# NEW SEX POP SIZE: (5, 360)
# (5, 432)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 287
# NEW SEX POP SIZE: (5, 358)
# (5, 432)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 295
# NEW SEX POP SIZE: (5, 368)
# (5, 421)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 287
# NEW SEX POP SIZE: (5, 358)
# (5, 430)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 422)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 421)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 412)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 302
# NEW SEX POP SIZE: (5, 377)
# (5, 406)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 415)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 407)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 406)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 406)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 301
# NEW SEX POP SIZE: (5, 376)
# (5, 401)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 408)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 410)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 290
# NEW SEX POP SIZE: (5, 362)
# (5, 412)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 292
# NEW SEX POP SIZE: (5, 365)
# (5, 408)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 398)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 300
# NEW SEX POP SIZE: (5, 375)
# (5, 395)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 289
# NEW SEX POP SIZE: (5, 361)
# (5, 408)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 294
# NEW SEX POP SIZE: (5, 367)
# (5, 401)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 295
# NEW SEX POP SIZE: (5, 368)
# (5, 398)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 398)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 280
# NEW SEX POP SIZE: (5, 350)
# (5, 413)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 276
# NEW SEX POP SIZE: (5, 345)
# (5, 417)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 278
# NEW SEX POP SIZE: (5, 347)
# (5, 413)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 286
# NEW SEX POP SIZE: (5, 357)
# (5, 402)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 286
# NEW SEX POP SIZE: (5, 357)
# (5, 401)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 280
# NEW SEX POP SIZE: (5, 350)
# (5, 407)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 290
# NEW SEX POP SIZE: (5, 362)
# (5, 393)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 388)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 293
# NEW SEX POP SIZE: (5, 366)
# (5, 387)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 380)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 298
# NEW SEX POP SIZE: (5, 372)
# (5, 378)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 307
# NEW SEX POP SIZE: (5, 383)
# (5, 366)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 312
# NEW SEX POP SIZE: (5, 390)
# (5, 358)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 350)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 348)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 312
# NEW SEX POP SIZE: (5, 390)
# (5, 355)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 342)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 345)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 315
# NEW SEX POP SIZE: (5, 393)
# (5, 348)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 342)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 310
# NEW SEX POP SIZE: (5, 387)
# (5, 351)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 309
# NEW SEX POP SIZE: (5, 386)
# (5, 351)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 314
# NEW SEX POP SIZE: (5, 392)
# (5, 343)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 305
# NEW SEX POP SIZE: (5, 381)
# (5, 353)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 299
# NEW SEX POP SIZE: (5, 373)
# (5, 360)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 306
# NEW SEX POP SIZE: (5, 382)
# (5, 350)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 301
# NEW SEX POP SIZE: (5, 376)
# (5, 355)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 313
# NEW SEX POP SIZE: (5, 391)
# (5, 338)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 314
# NEW SEX POP SIZE: (5, 392)
# (5, 336)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 330)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 331)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 315
# NEW SEX POP SIZE: (5, 393)
# (5, 331)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 321)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 336
# NEW SEX POP SIZE: (5, 420)
# (5, 302)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 331
# NEW SEX POP SIZE: (5, 413)
# (5, 307)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 339
# NEW SEX POP SIZE: (5, 423)
# (5, 296)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 341
# NEW SEX POP SIZE: (5, 426)
# (5, 292)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 295)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 341
# NEW SEX POP SIZE: (5, 426)
# (5, 290)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 292)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 332
# NEW SEX POP SIZE: (5, 415)
# (5, 298)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 313)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 306)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 305)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 303)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 327
# NEW SEX POP SIZE: (5, 408)
# (5, 296)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 297)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 300)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 301)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 295)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 288)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 298)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 292)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 298)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 297)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 315
# NEW SEX POP SIZE: (5, 393)
# (5, 300)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 288)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 285)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 327
# NEW SEX POP SIZE: (5, 408)
# (5, 281)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 326
# NEW SEX POP SIZE: (5, 407)
# (5, 281)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 287)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 288)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 315
# NEW SEX POP SIZE: (5, 393)
# (5, 291)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 285)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 327
# NEW SEX POP SIZE: (5, 408)
# (5, 273)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 262)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 335
# NEW SEX POP SIZE: (5, 418)
# (5, 260)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 332
# NEW SEX POP SIZE: (5, 415)
# (5, 262)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 326
# NEW SEX POP SIZE: (5, 407)
# (5, 268)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 271)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 317
# NEW SEX POP SIZE: (5, 396)
# (5, 277)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 272)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 272)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 323
# NEW SEX POP SIZE: (5, 403)
# (5, 266)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 251)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 268)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 319
# NEW SEX POP SIZE: (5, 398)
# (5, 266)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 321
# NEW SEX POP SIZE: (5, 401)
# (5, 262)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 326
# NEW SEX POP SIZE: (5, 407)
# (5, 255)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 243)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 332
# NEW SEX POP SIZE: (5, 415)
# (5, 245)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 340
# NEW SEX POP SIZE: (5, 425)
# (5, 235)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 339
# NEW SEX POP SIZE: (5, 423)
# (5, 236)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 248)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 252)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 330
# NEW SEX POP SIZE: (5, 412)
# (5, 243)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 330
# NEW SEX POP SIZE: (5, 412)
# (5, 242)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 331
# NEW SEX POP SIZE: (5, 413)
# (5, 240)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 242)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 251)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 317
# NEW SEX POP SIZE: (5, 396)
# (5, 253)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 238)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 331
# NEW SEX POP SIZE: (5, 413)
# (5, 233)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 238)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 248)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 242)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 238)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 240)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 237)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 233)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 240)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 330
# NEW SEX POP SIZE: (5, 412)
# (5, 223)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 333
# NEW SEX POP SIZE: (5, 416)
# (5, 218)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 341
# NEW SEX POP SIZE: (5, 426)
# (5, 207)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 341
# NEW SEX POP SIZE: (5, 426)
# (5, 206)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 208)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 337
# NEW SEX POP SIZE: (5, 421)
# (5, 208)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 336
# NEW SEX POP SIZE: (5, 420)
# (5, 208)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 205)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 338
# NEW SEX POP SIZE: (5, 422)
# (5, 203)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 193)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 346
# NEW SEX POP SIZE: (5, 432)
# (5, 191)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 340
# NEW SEX POP SIZE: (5, 425)
# (5, 197)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 348
# NEW SEX POP SIZE: (5, 435)
# (5, 186)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 188)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 187)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 340
# NEW SEX POP SIZE: (5, 425)
# (5, 192)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 198)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 203)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 203)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 212)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 318
# NEW SEX POP SIZE: (5, 397)
# (5, 213)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 203)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 316
# NEW SEX POP SIZE: (5, 395)
# (5, 213)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 312
# NEW SEX POP SIZE: (5, 390)
# (5, 217)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 313
# NEW SEX POP SIZE: (5, 391)
# (5, 215)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 205)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 320
# NEW SEX POP SIZE: (5, 400)
# (5, 205)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 324
# NEW SEX POP SIZE: (5, 405)
# (5, 200)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 325
# NEW SEX POP SIZE: (5, 406)
# (5, 198)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 322
# NEW SEX POP SIZE: (5, 402)
# (5, 201)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 321
# NEW SEX POP SIZE: (5, 401)
# (5, 201)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 328
# NEW SEX POP SIZE: (5, 410)
# (5, 191)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 329
# NEW SEX POP SIZE: (5, 411)
# (5, 188)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 330
# NEW SEX POP SIZE: (5, 412)
# (5, 186)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 334
# NEW SEX POP SIZE: (5, 417)
# (5, 180)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 339
# NEW SEX POP SIZE: (5, 423)
# (5, 172)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 337
# NEW SEX POP SIZE: (5, 421)
# (5, 173)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 343
# NEW SEX POP SIZE: (5, 428)
# (5, 165)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 345
# NEW SEX POP SIZE: (5, 431)
# (5, 161)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 347
# NEW SEX POP SIZE: (5, 433)
# (5, 157)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 347
# NEW SEX POP SIZE: (5, 433)
# (5, 156)
# ASEX AVG FITNESS:  2904.2448979591836
# SEX AVG FITNESS:  2904.019011406844
# PRE REPLICATION SEX POP SIZE: 339
# ...
# (5, 605)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 93
# NEW SEX POP SIZE: (5, 116)
# (5, 608)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 84
# NEW SEX POP SIZE: (5, 105)
# (5, 618)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 85
# NEW SEX POP SIZE: (5, 106)
# (5, 616)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 87
# NEW SEX POP SIZE: (5, 108)
# (5, 612)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 90
# NEW SEX POP SIZE: (5, 112)
# (5, 607)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 93
# NEW SEX POP SIZE: (5, 116)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 89
# NEW SEX POP SIZE: (5, 111)
# (5, 606)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 87
# NEW SEX POP SIZE: (5, 108)
# (5, 607)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 83
# NEW SEX POP SIZE: (5, 103)
# (5, 611)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 80
# NEW SEX POP SIZE: (5, 100)
# (5, 613)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 84
# NEW SEX POP SIZE: (5, 105)
# (5, 607)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 84
# NEW SEX POP SIZE: (5, 105)
# (5, 606)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 85
# NEW SEX POP SIZE: (5, 106)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 85
# NEW SEX POP SIZE: (5, 106)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 83
# NEW SEX POP SIZE: (5, 103)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 85
# NEW SEX POP SIZE: (5, 106)
# (5, 598)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 86
# NEW SEX POP SIZE: (5, 107)
# (5, 596)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 81
# NEW SEX POP SIZE: (5, 101)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 79
# NEW SEX POP SIZE: (5, 98)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 79
# NEW SEX POP SIZE: (5, 98)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 82
# NEW SEX POP SIZE: (5, 102)
# (5, 596)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 82
# NEW SEX POP SIZE: (5, 102)
# (5, 595)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 78
# NEW SEX POP SIZE: (5, 97)
# (5, 598)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 74
# NEW SEX POP SIZE: (5, 92)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 75
# NEW SEX POP SIZE: (5, 93)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 72
# NEW SEX POP SIZE: (5, 90)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 63
# NEW SEX POP SIZE: (5, 78)
# (5, 612)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 57
# NEW SEX POP SIZE: (5, 71)
# (5, 618)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 58
# NEW SEX POP SIZE: (5, 72)
# (5, 616)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 60
# NEW SEX POP SIZE: (5, 75)
# (5, 612)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 62
# NEW SEX POP SIZE: (5, 77)
# (5, 608)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 60
# NEW SEX POP SIZE: (5, 75)
# (5, 610)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 59
# NEW SEX POP SIZE: (5, 73)
# (5, 611)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 62
# NEW SEX POP SIZE: (5, 77)
# (5, 606)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 63
# NEW SEX POP SIZE: (5, 78)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 64
# NEW SEX POP SIZE: (5, 80)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 64
# NEW SEX POP SIZE: (5, 80)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 70
# NEW SEX POP SIZE: (5, 87)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 62
# NEW SEX POP SIZE: (5, 77)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 62
# NEW SEX POP SIZE: (5, 77)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 64
# NEW SEX POP SIZE: (5, 80)
# (5, 596)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 67
# NEW SEX POP SIZE: (5, 83)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 64
# NEW SEX POP SIZE: (5, 80)
# (5, 593)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 60
# NEW SEX POP SIZE: (5, 75)
# (5, 597)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 57
# NEW SEX POP SIZE: (5, 71)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 58
# NEW SEX POP SIZE: (5, 72)
# (5, 597)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 53
# NEW SEX POP SIZE: (5, 66)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 53
# NEW SEX POP SIZE: (5, 66)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 53
# NEW SEX POP SIZE: (5, 66)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 51
# NEW SEX POP SIZE: (5, 63)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 49
# NEW SEX POP SIZE: (5, 61)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 43
# NEW SEX POP SIZE: (5, 53)
# (5, 608)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 39
# NEW SEX POP SIZE: (5, 48)
# (5, 611)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 40
# NEW SEX POP SIZE: (5, 50)
# (5, 608)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 40
# NEW SEX POP SIZE: (5, 50)
# (5, 607)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 42
# NEW SEX POP SIZE: (5, 52)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 41
# NEW SEX POP SIZE: (5, 51)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 40
# NEW SEX POP SIZE: (5, 50)
# (5, 603)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 43
# NEW SEX POP SIZE: (5, 53)
# (5, 598)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 46
# NEW SEX POP SIZE: (5, 57)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 47
# NEW SEX POP SIZE: (5, 58)
# (5, 590)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 46
# NEW SEX POP SIZE: (5, 57)
# (5, 590)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 43
# NEW SEX POP SIZE: (5, 53)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 44
# NEW SEX POP SIZE: (5, 55)
# (5, 590)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 44
# NEW SEX POP SIZE: (5, 55)
# (5, 590)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 43
# NEW SEX POP SIZE: (5, 53)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 38
# NEW SEX POP SIZE: (5, 47)
# (5, 596)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 39
# NEW SEX POP SIZE: (5, 48)
# (5, 593)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 38
# NEW SEX POP SIZE: (5, 47)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 38
# NEW SEX POP SIZE: (5, 47)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 37
# NEW SEX POP SIZE: (5, 46)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 41
# NEW SEX POP SIZE: (5, 51)
# (5, 585)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 45
# NEW SEX POP SIZE: (5, 56)
# (5, 578)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 40
# NEW SEX POP SIZE: (5, 50)
# (5, 583)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 39
# NEW SEX POP SIZE: (5, 48)
# (5, 583)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 33
# NEW SEX POP SIZE: (5, 41)
# (5, 588)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 30
# NEW SEX POP SIZE: (5, 37)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 30
# NEW SEX POP SIZE: (5, 37)
# (5, 590)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 28
# NEW SEX POP SIZE: (5, 35)
# (5, 591)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 25
# NEW SEX POP SIZE: (5, 31)
# (5, 593)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 25
# NEW SEX POP SIZE: (5, 31)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 24
# NEW SEX POP SIZE: (5, 30)
# (5, 592)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 22
# NEW SEX POP SIZE: (5, 27)
# (5, 593)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 19
# NEW SEX POP SIZE: (5, 23)
# (5, 596)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 14
# NEW SEX POP SIZE: (5, 17)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 10
# NEW SEX POP SIZE: (5, 12)
# (5, 605)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 11
# NEW SEX POP SIZE: (5, 13)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 8
# NEW SEX POP SIZE: (5, 10)
# (5, 605)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 7
# NEW SEX POP SIZE: (5, 8)
# (5, 606)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 7
# NEW SEX POP SIZE: (5, 8)
# (5, 605)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 8
# NEW SEX POP SIZE: (5, 10)
# (5, 602)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 8
# NEW SEX POP SIZE: (5, 10)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 9
# NEW SEX POP SIZE: (5, 11)
# (5, 598)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 7
# NEW SEX POP SIZE: (5, 8)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 5
# NEW SEX POP SIZE: (5, 6)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 4
# NEW SEX POP SIZE: (5, 5)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 4
# NEW SEX POP SIZE: (5, 5)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 4
# NEW SEX POP SIZE: (5, 5)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 4
# NEW SEX POP SIZE: (5, 5)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 4
# NEW SEX POP SIZE: (5, 5)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 3
# NEW SEX POP SIZE: (5, 3)
# (5, 601)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 3
# NEW SEX POP SIZE: (5, 3)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 2
# NEW SEX POP SIZE: (5, 2)
# (5, 600)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 2
# NEW SEX POP SIZE: (5, 2)
# (5, 598)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 2
# NEW SEX POP SIZE: (5, 2)
# (5, 597)
# ASEX AVG FITNESS:  2962.0309278350514
# SEX AVG FITNESS:  2966.9561403508774
# PRE REPLICATION SEX POP SIZE: 1
# NEW SEX POP SIZE: (0,)
# (5, 597)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b8cf1b95e809> in <module>
#       8         gia.mutation_stage(step = 1, mutation_liklihood=0.02)
#       9         gia.survival_round()
# ---> 10         gia.replication_round()
#      11         if gia.species_sep_index>900:
#      12             asexual_success += 1
#
# <ipython-input-17-ea9b892aca51> in replication_round(self)
#     144         print('NEW SEX POP SIZE:', new_sex_pop.shape)
#     145         print(new_asex_pop.shape)
# --> 146         self.total_pop_mat = np.concatenate([new_asex_pop,new_sex_pop], axis=1)
#     147         self.species_sep_index = (new_asex_pop.shape)[1]
#     148
#
# ValueError: all the input arrays must have same number of dimensions

# %%
plt.plot(asexual_pop)

# %%
lengths_original_average = 1439.546
lengths_orignial_sd = 923.79
